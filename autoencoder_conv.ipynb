# %%
import tensorflow as tf
import os

import neurokit2 as nk


import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.keras import TqdmCallback

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D, Flatten, Input, Conv1DTranspose, Conv2DTranspose, Reshape
from tensorflow.keras.optimizers import Adam
from keras.utils import to_categorical
import tensorflow as tf

from matplotlib.offsetbox import OffsetImage, AnnotationBbox

sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# Device mapping: no known devices.

# %%
ecg100 = nk.ecg_simulate(duration=10, noise=0.01, heart_rate=100)

ecg_df = pd.DataFrame({"ECG_100": ecg100})

nk.signal_plot(ecg100)

# %%
type(ecg100)
# Out:
# numpy.ndarray

# %%
ecg100.shape
# Out:
# (10000,)

# %%
encoder = tf.keras.models.Sequential([
    Conv1D(64, 10, activation='relu', padding='same', input_shape=(10000, 1)),
    Dense(32, activation='relu'),
    MaxPooling1D(),
    Conv1D(32, 10, activation='relu', padding='same'),
    Dense(16, activation='relu'),
    MaxPooling1D(),
    Flatten(),
    Dense(8)
    
], name='encoder')

# %%
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10000, 64)         704
#
#  dense_6 (Dense)             (None, 10000, 32)         2080
#
#  max_pooling1d (MaxPooling1  (None, 5000, 32)          0
#  D)
#
#  conv1d_4 (Conv1D)           (None, 5000, 32)          10272
#
#  dense_7 (Dense)             (None, 5000, 16)          528
#
#  max_pooling1d_1 (MaxPoolin  (None, 2500, 16)          0
#  g1D)
#
#  flatten_2 (Flatten)         (None, 40000)             0
#
#  dense_8 (Dense)             (None, 8)                 320008
#
# =================================================================
# Total params: 333592 (1.27 MB)
# Trainable params: 333592 (1.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
decoder = tf.keras.models.Sequential([
    Reshape((8, 1)),
    Conv1DTranspose(8, 9993, activation='relu', input_shape=(8, 1)),
    Dense(16, activation='relu'),
    Conv1DTranspose(16, 100, activation='relu', padding='same'),
    Dense(32, activation='relu'),
    Conv1DTranspose(32, 10, activation='relu', padding='same'),
    Dense(64, activation='relu'),
    Conv1DTranspose(1, 10, activation='relu', padding='same'),
], name='decoder')

# %%
autoencoder = Sequential([encoder, decoder])
autoencoder.summary(expand_nested=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Sequential)        (None, 8)                 333592
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv1d_3 (Conv1D)          (None, 10000, 64)         704      |
# |                                                               |
# | dense_6 (Dense)            (None, 10000, 32)         2080     |
# |                                                               |
# | max_pooling1d (MaxPooling  (None, 5000, 32)          0        |
# | 1D)                                                           |
# |                                                               |
# | conv1d_4 (Conv1D)          (None, 5000, 32)          10272    |
# |                                                               |
# | dense_7 (Dense)            (None, 5000, 16)          528      |
# |                                                               |
# | max_pooling1d_1 (MaxPooli  (None, 2500, 16)          0        |
# | ng1D)                                                         |
# |                                                               |
# | flatten_2 (Flatten)        (None, 40000)             0        |
# |                                                               |
# | dense_8 (Dense)            (None, 8)                 320008   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  decoder (Sequential)        (None, 10000, 1)          119281
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | reshape_2 (Reshape)        (None, 8, 1)              0        |
# |                                                               |
# | conv1d_transpose_38 (Conv  (None, 10000, 8)          79952    |
# | 1DTranspose)                                                  |
# |                                                               |
# | dense_39 (Dense)           (None, 10000, 16)         144      |
# |                                                               |
# | conv1d_transpose_39 (Conv  (None, 10000, 16)         25616    |
# | 1DTranspose)                                                  |
# |                                                               |
# | dense_40 (Dense)           (None, 10000, 32)         544      |
# |                                                               |
# | conv1d_transpose_40 (Conv  (None, 10000, 32)         10272    |
# | 1DTranspose)                                                  |
# |                                                               |
# | dense_41 (Dense)           (None, 10000, 64)         2112     |
# |                                                               |
# | conv1d_transpose_41 (Conv  (None, 10000, 1)          641      |
# | 1DTranspose)                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 452873 (1.73 MB)
# Trainable params: 452873 (1.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.compile(optimizer = "adam", loss = "mse")
history = autoencoder.fit(ecg100.reshape(1, -1), ecg100.reshape(1, -1), batch_size = 128, epochs = 10, verbose = 0, callbacks=[TqdmCallback(verbose=1)])
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
plot_df = pd.DataFrame.from_dict({'train_loss':history.history['loss']})
plot_df.plot(logy=True, figsize=(15,5), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.show()

# %%
encoder.predict(ecg100.reshape(1, -1))
# Out:
# 1/1 [==============================] - 0s 107ms/step
# array([[-0.5975452 , -0.7427834 , -1.3369915 , -1.5324949 , -0.6921962 ,
#         -1.3740534 , -0.89263207, -1.7043905 ]], dtype=float32)

# %%
ten_subjects = pd.read_csv('ecg_10_subjects.csv')

# %%
ten_subjects.shape
# Out:
# (300000, 1)

# %%
ten_subjects_reshaped = ten_subjects.values.reshape((10, 30000, 1))
ten_subjects_reshaped.shape
# Out:
# (10, 30000, 1)

# %%
encoder = tf.keras.models.Sequential([
    Conv1D(64, 10, activation='relu', padding='same', input_shape=(30000, 1)),
    Dense(32, activation='relu'),
    MaxPooling1D(),
    Conv1D(32, 10, activation='relu', padding='same'),
    Dense(16, activation='relu'),
    MaxPooling1D(),
    Flatten(),
    Dense(8)
    
], name='encoder')

# %%
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (None, 30000, 64)         704
#
#  dense_60 (Dense)            (None, 30000, 32)         2080
#
#  max_pooling1d_10 (MaxPooli  (None, 15000, 32)         0
#  ng1D)
#
#  conv1d_12 (Conv1D)          (None, 15000, 32)         10272
#
#  dense_61 (Dense)            (None, 15000, 16)         528
#
#  max_pooling1d_11 (MaxPooli  (None, 7500, 16)          0
#  ng1D)
#
#  flatten_7 (Flatten)         (None, 120000)            0
#
#  dense_62 (Dense)            (None, 8)                 960008
#
# =================================================================
# Total params: 973592 (3.71 MB)
# Trainable params: 973592 (3.71 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
decoder = tf.keras.models.Sequential([
    Reshape((8, 1)),
    Conv1DTranspose(8, 29993, activation='relu', input_shape=(8, 1)),
    Dense(16, activation='relu'),
    Conv1DTranspose(16, 100, activation='relu', padding='same'),
    Dense(32, activation='relu'),
    Conv1DTranspose(32, 10, activation='relu', padding='same'),
    Dense(64, activation='relu'),
    Conv1DTranspose(1, 10, activation='relu', padding='same'),
], name='decoder')

# %%
decoder.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 decoder.summary()
#
# File ~/opt/anaconda3/envs/ecg-embeddings/lib/python3.9/site-packages/keras/src/engine/training.py:3506, in Model.summary(self, line_length, positions, print_fn, expand_nested, show_trainable, layer_range)
#    3475 """Prints a string summary of the network.
#    3476
#    3477 Args:
#    (...)
#    3503     ValueError: if `summary()` is called before the model is built.
#    3504 """
#    3505 if not self.built:
# -> 3506     raise ValueError(
#    3507         "This model has not yet been built. "
#    3508         "Build the model first by calling `build()` or by calling "
#    3509         "the model on a batch of data."
#    3510     )
#    3511 layer_utils.print_summary(
#    3512     self,
#    3513     line_length=line_length,
#    (...)
#    3518     layer_range=layer_range,
#    3519 )
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.

# %%
autoencoder = Sequential([encoder, decoder])
autoencoder.summary(expand_nested=True)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Sequential)        (None, 8)                 973592
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv1d_11 (Conv1D)         (None, 30000, 64)         704      |
# |                                                               |
# | dense_60 (Dense)           (None, 30000, 32)         2080     |
# |                                                               |
# | max_pooling1d_10 (MaxPool  (None, 15000, 32)         0        |
# | ing1D)                                                        |
# |                                                               |
# | conv1d_12 (Conv1D)         (None, 15000, 32)         10272    |
# |                                                               |
# | dense_61 (Dense)           (None, 15000, 16)         528      |
# |                                                               |
# | max_pooling1d_11 (MaxPool  (None, 7500, 16)          0        |
# | ing1D)                                                        |
# |                                                               |
# | flatten_7 (Flatten)        (None, 120000)            0        |
# |                                                               |
# | dense_62 (Dense)           (None, 8)                 960008   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  decoder (Sequential)        (None, 30000, 1)          279281
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | reshape_4 (Reshape)        (None, 8, 1)              0        |
# |                                                               |
# | conv1d_transpose_54 (Conv  (None, 30000, 8)          239952   |
# | 1DTranspose)                                                  |
# |                                                               |
# | dense_63 (Dense)           (None, 30000, 16)         144      |
# |                                                               |
# | conv1d_transpose_55 (Conv  (None, 30000, 16)         25616    |
# | 1DTranspose)                                                  |
# |                                                               |
# | dense_64 (Dense)           (None, 30000, 32)         544      |
# |                                                               |
# | conv1d_transpose_56 (Conv  (None, 30000, 32)         10272    |
# | 1DTranspose)                                                  |
# |                                                               |
# | dense_65 (Dense)           (None, 30000, 64)         2112     |
# |                                                               |
# | conv1d_transpose_57 (Conv  (None, 30000, 1)          641      |
# | 1DTranspose)                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 1252873 (4.78 MB)
# Trainable params: 1252873 (4.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.compile(optimizer = "adam", loss = "mse")
history = autoencoder.fit(ten_subjects_reshaped, ten_subjects_reshaped, batch_size = 128, epochs = 10, verbose = 0, callbacks=[TqdmCallback(verbose=1)])
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
plot_df = pd.DataFrame.from_dict({'train_loss':history.history['loss']})
plot_df.plot(logy=True, figsize=(15,5), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.show()

# %%
encoder.predict(ten_subjects_reshaped)
# Out:
# 1/1 [==============================] - 0s 128ms/step
# array([[-0.12427819, -0.25834692, -0.36581922, -0.46153352, -0.3062214 ,
#         -0.22339219, -0.32341316, -0.16666844],
#        [-0.18408631, -0.50434345, -0.54140997, -0.6516467 , -0.46311966,
#         -0.32471272, -0.47331452, -0.19312617],
#        [ 0.35594875, -0.1150392 , -0.19132443, -0.6329289 , -0.28679794,
#          0.01756968, -0.25674558,  0.4111481 ],
#        [-0.18403359, -0.5300314 , -0.4631301 , -0.6149047 , -0.43235543,
#         -0.29544255, -0.46746323, -0.09521813],
#        [-0.36766002, -0.68947977, -0.7715529 , -0.8998534 , -0.68216914,
#         -0.47779232, -0.6846957 , -0.34375075],
#        [-0.15472159, -0.2865723 , -0.3060346 , -0.38504753, -0.28324822,
#         -0.20603013, -0.2931874 , -0.14226629],
#        [-1.8904424 , -1.97125   , -2.1086028 , -2.233131  , -2.014934  ,
#         -1.9979231 , -1.9554373 , -1.7972519 ],
#        [-0.14687906, -0.3108665 , -0.3649409 , -0.44917563, -0.33419457,
#         -0.24857578, -0.3566708 , -0.1335753 ],
#        [-0.20549545, -0.38619155, -0.45942158, -0.5268282 , -0.3973281 ,
#         -0.2677758 , -0.4002055 , -0.15273517],
#        [-0.23469402, -0.41645563, -0.5124422 , -0.64119655, -0.43369606,
#         -0.41639662, -0.43972293, -0.21517473]], dtype=float32)
